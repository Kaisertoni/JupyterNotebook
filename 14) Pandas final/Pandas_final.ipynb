# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### <span style='background :yellow'>Import di un dataframe
#     Per tutti i formati:
#     - se il dataframe non contiene le colonne si imposta header = None
#     - per impostare il nome delle colonne si utilizza il parametro names = [lista]

# %% [markdown]
# #### <span style='background :lime'>File CSV

# %%
df = pd.read_csv('./Dataset/pokemon_data.csv')

# %% [markdown]
# #### <span style='background :lime'>File Excel

# %%
df = pd.read_excel('./Dataset/pokemon_data.xlsx')

# %% [markdown]
# #### <span style='background :lime'>File TXT

# %%
df = pd.read_csv('./Dataset/pokemon_data.txt', delimiter='\t') # \t sta per il tasto tab

# %%
df
# Out:
#        #                   Name   Type 1  Type 2    HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison   NaN      49       49
# 1      2                Ivysaur    Grass  Poison  60.0      62       60
# 2      2                Ivysaur    Grass  Poison  60.0      62       60
# 3      3               Venusaur    Grass  Poison  80.0      82       83
# 4      3  VenusaurMega Venusaur    Grass  Poison  80.0     100      123
# ..   ...                    ...      ...     ...   ...     ...      ...
# 796  719                Diancie     Rock   Fairy  50.0     100      150
# 797  719    DiancieMega Diancie     Rock   Fairy  50.0     160      110
# 798  720    HoopaHoopa Confined  Psychic   Ghost  80.0     110       60
# 799  720     HoopaHoopa Unbound  Psychic    Dark  80.0     160       60
# 800  721              Volcanion     Fire   Water  80.0     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### <span style='background :yellow'>Export di un dataframe

# %% [markdown]
# #### Esportare come CSV

# %%
df.to_csv('./Dataset/pokemon_data_modified.csv', index=False) # index=False permette di non salvare l'indice del dataframe

# %% [markdown]
# #### Esportare come EXCEL

# %%
df.to_excel('./Dataset/pokemon_data_modified.xlsx', index=False) # index=False permette di non salvare l'indice del dataframe

# %% [markdown]
# #### Esportare come TXT

# %%
df.to_csv('./Dataset/pokemon_data_modified.txt', index=False, sep='\t') # index=False permette di non salvare l'indice del dataframe

# %% [markdown]
# ### <span style='background :yellow'>Ispezione del dataframe

# %% [markdown]
# ![Immagine.png](attachment:Immagine.png)

# %% [markdown]
# #### <span style='background :lime'>Funzione HEAD( )
#     Ritorna le prime n osservazione del dataframe

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison   NaN      49       49       65
# 1  2                Ivysaur  Grass  Poison  60.0      62       60       80
# 2  2                Ivysaur  Grass  Poison  60.0      62       60       80
# 3  3               Venusaur  Grass  Poison  80.0      82       83      100
# 4  3  VenusaurMega Venusaur  Grass  Poison  80.0     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 4      120     80           1      False

# %% [markdown]
# #### <span style='background :lime'>Funzione TAIL( )
#     Ritorna le ultime n osservazione del dataframe

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2    HP  Attack  Defense  Sp. Atk  \
# 796  719              Diancie     Rock  Fairy  50.0     100      150      100
# 797  719  DiancieMega Diancie     Rock  Fairy  50.0     160      110      160
# 798  720  HoopaHoopa Confined  Psychic  Ghost  80.0     110       60      150
# 799  720   HoopaHoopa Unbound  Psychic   Dark  80.0     160       60      170
# 800  721            Volcanion     Fire  Water  80.0     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 796      150     50           6       True
# 797      110    110           6       True
# 798      130     70           6       True
# 799      130     80           6       True
# 800       90     70           6       True

# %% [markdown]
# #### <span style='background :lime'>Funzione INFO( )
#     Ritorna alcune info sul dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           801 non-null    int64
#  1   Name        801 non-null    object
#  2   Type 1      801 non-null    object
#  3   Type 2      415 non-null    object
#  4   HP          800 non-null    float64
#  5   Attack      801 non-null    int64
#  6   Defense     801 non-null    int64
#  7   Sp. Atk     801 non-null    int64
#  8   Sp. Def     801 non-null    int64
#  9   Speed       801 non-null    int64
#  10  Generation  801 non-null    int64
#  11  Legendary   801 non-null    bool
# dtypes: bool(1), float64(1), int64(7), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# #### <span style='background :lime'>Funzione SHAPE
#     Ritorna numero di righe e colonne del dataframe

# %%
df.shape
# Out:
# (801, 12)

# %% [markdown]
# #### <span style='background :lime'>Funzione DTYPES
#     Ritorna il tipo delle colonne

# %%
df.dtypes
# Out:
# #               int64
# Name           object
# Type 1         object
# Type 2         object
# HP            float64
# Attack          int64
# Defense         int64
# Sp. Atk         int64
# Sp. Def         int64
# Speed           int64
# Generation      int64
# Legendary        bool
# dtype: object

# %% [markdown]
# #### <span style='background :lime'>Funzione COLUMNS
#     Ritorna le colonne del dataframe

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# #### <span style='background :lime'>Funzione INDEX
#     Ritorna l'indice del dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=801, step=1)

# %% [markdown]
# #### <span style='background :lime'>Funzione DESCRIBE( )
#     Ritorna informazioni statistiche su tutte le features del dataframe

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  801.000000  800.000000  801.000000  801.000000  801.000000  801.000000
# mean   362.363296   69.277500   78.980025   73.821473   72.828964   71.912609
# std    208.603473   25.522338   32.442636   31.169325   32.702820   27.812989
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.000000   50.000000   55.000000   50.000000   50.000000   50.000000
# 50%    364.000000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.000000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  801.000000  801.000000
# mean    68.267166    3.320849
# std     29.043778    1.662281
# min      5.000000    1.000000
# 25%     45.000000    2.000000
# 50%     65.000000    3.000000
# 75%     90.000000    5.000000
# ...

# %% [markdown]
# #### <span style='background :lime'>Funzione AGG( )
#     Permette di applicare oltre alle solite funzioni (media, mediana, std, etc.) delle funzioni custom alle
#     colonne

# %% [markdown]
# ![Immagine.png](attachment:Immagine.png)

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

# %%
df['HP'].agg(iqr)
# Out:
# 30.0

# %%
df[['HP','Attack']].agg(iqr)
# Out:
# HP        30.0
# Attack    45.0
# dtype: float64

# %%
df[['HP','Attack']].agg([iqr, np.mean, np.median])
# Out:
#              HP     Attack
# iqr     30.0000  45.000000
# mean    69.2775  78.980025
# median  65.0000  75.000000

# %% [markdown]
# #### <span style='background :lime'>Funzione UNIQUE( )
#     Ritorna singolarmente tutti i valori  presenti all'interno di una colonna

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# #### <span style='background :lime'>Funzione VALUE_COUNTS( )
#     Ritorna il numero di occorrenze di ogni valore presente all'interno di una colonna
#
#     Parametri:
#     - sort: se impostato a True fa il sorting dei valori
#     - normalize: se impostato a True normalizza i valori per capire come si distribuiscono

# %%
df['Type 1'].value_counts(sort=False, normalize=False)
# Out:
# Grass        71
# Fire         52
# Water       112
# Bug          69
# Normal       98
# Poison       28
# Electric     44
# Ground       32
# Fairy        17
# Fighting     27
# Psychic      57
# Rock         44
# Ghost        32
# Ice          24
# Dragon       32
# Dark         31
# Steel        27
# Flying        4
# Name: Type 1, dtype: int64

# %%
df['Type 1'].value_counts(sort=True, normalize=True)
# Out:
# Water       0.139825
# Normal      0.122347
# Grass       0.088639
# Bug         0.086142
# Psychic     0.071161
# Fire        0.064919
# Electric    0.054931
# Rock        0.054931
# Dragon      0.039950
# Ground      0.039950
# Ghost       0.039950
# Dark        0.038702
# Poison      0.034956
# Steel       0.033708
# Fighting    0.033708
# Ice         0.029963
# Fairy       0.021223
# Flying      0.004994
# Name: Type 1, dtype: float64

# %% [markdown]
# ### <span style='background :yellow'>Gestione dei valori nulli

# %% [markdown]
# #### <span style='background :lime'>Conteggio dei valori

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              1
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# #### <span style='background :lime'> Fill dei valori nulli - funzione FILLNA( )

# %%
df_fill_na = df.copy()

# %%
df_fill_na['Type 2'] = df_fill_na['Type 2'].fillna('No type')

# %%
df_fill_na['HP'] = df_fill_na['HP'].fillna(round(df_fill_na['HP'].mean()))

# %%
df_fill_na.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df_fill_na.shape # i valori nulli sono stati rimpiazzati, il numero di righe rimane lo stesso
# Out:
# (801, 12)

# %% [markdown]
# #### <span style='background :lime'> Eliminazione dei valori nulli - funzione DROPNA( )

# %%
df_drop_na = df.copy()

# %%
# eliminazione delle sole righe con valore nullo nella colonna Type 2
df_drop_na = df.dropna(subset=['Type 2'])
df_drop_na.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            1
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
# eliminazione delle righe con valore nullo in qualsiasi colonna
df_drop_na = df_drop_na.dropna()
df_drop_na.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df_drop_na.shape # le righe con valori nulli sono state eliminate, il numero di righe diminuisce
# Out:
# (414, 12)

# %% [markdown]
# ### <span style='background :yellow'>Gestione dei duplicati

# %% [markdown]
# #### <span style='background :lime'>Conteggio dei valori

# %%
# df.pivot_table(columns=['DataFrame Columns'], aggfunc='size').sort_values(ascending=False)

# %%
# conteggio dei duplicati considerando una singola colonna
df.pivot_table(columns=['HP'], aggfunc='size').sort_values(ascending=False)
# Out:
# HP
# 60.0     68
# 50.0     63
# 70.0     57
# 65.0     46
# 75.0     43
#          ..
# 97.0      1
# 99.0      1
# 101.0     1
# 104.0     1
# 255.0     1
# Length: 94, dtype: int64

# %%
# conteggio dei duplicati considerando tutte le colonne
df.pivot_table(columns=df.columns.values.tolist()[1:], aggfunc='size').sort_values(ascending=False)
# Out:
# Name              Type 1   Type 2  HP     Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Ivysaur           Grass    Poison  60.0   62      60       80       80       60     1           False        2
# Abomasnow         Grass    Ice     90.0   92      75       92       85       60     4           False        1
# Probopass         Rock     Steel   60.0   55      145      75       150      40     4           False        1
# Rayquaza          Dragon   Flying  105.0  150     90       150      90       95     3           True         1
# Ralts             Psychic  Fairy   28.0   25      25       45       35       40     3           False        1
#                                                                                                             ..
# Golurk            Ground   Ghost   89.0   124     80       55       80       55     5           False        1
# ...

# %% [markdown]
# #### <span style='background :lime'> Eliminazione dei duplicati - funzione DROP_DUPLICATES( )

# %%
df_drop_duplicates = df.copy()

# %%
# eliminazione delle righe con duplicati solo nella colonna Name
df_drop_duplicates = df_drop_duplicates.drop_duplicates(subset=['Name'])

# %%
# eliminazione delle righe con duplicati in tutte le colonne
df_drop_duplicates = df_drop_duplicates.drop_duplicates()

# %%
# gestione dei duplicati e dei valori nulli in df
df.drop_duplicates(subset=['Name'], inplace=True)
df.loc[:,'Type 2'] = df['Type 2'].fillna('No type')
df.loc[:,'HP'] = df['HP'].fillna(round(df['HP'].mean()))

# %% [markdown]
# ### <span style='background :yellow'>Sorting delle righe

# %% [markdown]
# ![Immagine.png](attachment:Immagine.png)

# %%
df.head()
# Out:
#    #                   Name Type 1   Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass   Poison  69.0      49       49       65
# 1  2                Ivysaur  Grass   Poison  60.0      62       60       80
# 3  3               Venusaur  Grass   Poison  80.0      82       83      100
# 4  3  VenusaurMega Venusaur  Grass   Poison  80.0     100      123      122
# 5  4             Charmander   Fire  No type  39.0      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      100     80           1      False
# 4      120     80           1      False
# 5       50     65           1      False

# %% [markdown]
# #### <span style='background :lime'>Riordinamento del dataframe per colonna Name in ordine ascendente

# %%
df.sort_values('Name', ascending=True).head()
# Out:
#        #                     Name   Type 1   Type 2    HP  Attack  Defense  \
# 511  460                Abomasnow    Grass      Ice  90.0      92       75
# 512  460  AbomasnowMega Abomasnow    Grass      Ice  90.0     132      105
# 69    63                     Abra  Psychic  No type  25.0      20       15
# 393  359                    Absol     Dark  No type  65.0     130       60
# 394  359          AbsolMega Absol     Dark  No type  65.0     150       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 511       92       85     60           4      False
# 512      132      105     30           4      False
# 69       105       55     90           1      False
# 393       75       60     75           3      False
# 394      115       60    115           3      False

# %% [markdown]
# #### <span style='background :lime'>Riordinamento del dataframe per colonna Attaco e Difesa in ordine discendente per entrambi

# %%
df.sort_values(['Attack','Defense'], ascending=[False,False]).head()
# Out:
#        #                     Name   Type 1    Type 2     HP  Attack  Defense  \
# 164  150      MewtwoMega Mewtwo X  Psychic  Fighting  106.0     190      100
# 233  214  HeracrossMega Heracross      Bug  Fighting   80.0     185      115
# 425  383    GroudonPrimal Groudon   Ground      Fire  100.0     180      160
# 427  384    RayquazaMega Rayquaza   Dragon    Flying  105.0     180      100
# 430  386       DeoxysAttack Forme  Psychic   No type   50.0     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      154      100    130           1       True
# 233       40      105     75           2      False
# 425      150       90     90           3       True
# 427      180      100    115           3       True
# 430      180       20    150           3       True

# %% [markdown]
# ### <span style='background :yellow'>Subsetting delle colonne

# %% [markdown]
# ![Immagine.png](attachment:Immagine.png)

# %% [markdown]
# #### <span style='background :lime'>Singola colonna

# %%
df[['Name']].head()
# Out:
#                     Name
# 0              Bulbasaur
# 1                Ivysaur
# 3               Venusaur
# 4  VenusaurMega Venusaur
# 5             Charmander

# %% [markdown]
# #### <span style='background :lime'>Multiple colonne

# %%
df[['Name', 'Attack', 'Defense']].head()
# Out:
#                     Name  Attack  Defense
# 0              Bulbasaur      49       49
# 1                Ivysaur      62       60
# 3               Venusaur      82       83
# 4  VenusaurMega Venusaur     100      123
# 5             Charmander      52       43

# %% [markdown]
# ### <span style='background :yellow'>Subsetting delle righe

# %% [markdown]
# ![Immagine.png](attachment:Immagine.png)
# ![Immagine-2.png](attachment:Immagine-2.png)

# %% [markdown]
# #### <span style='background :lime'>Singola riga

# %%
df.iloc[[0]]
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  69.0      49       49       65       65
#
#    Speed  Generation  Legendary
# 0     45           1      False

# %% [markdown]
# #### <span style='background :lime'>Multiple righe

# %%
df.iloc[0:5]
# Out:
#    #                   Name Type 1   Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass   Poison  69.0      49       49       65
# 1  2                Ivysaur  Grass   Poison  60.0      62       60       80
# 3  3               Venusaur  Grass   Poison  80.0      82       83      100
# 4  3  VenusaurMega Venusaur  Grass   Poison  80.0     100      123      122
# 5  4             Charmander   Fire  No type  39.0      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      100     80           1      False
# 4      120     80           1      False
# 5       50     65           1      False

# %% [markdown]
# #### <span style='background :lime'>Su condizione

# %% [markdown]
# ##### Condizione singola

# %%
df[df['Attack'] == 170]
# Out:
#        #                   Name  Type 1  Type 2     HP  Attack  Defense  \
# 495  445  GarchompMega Garchomp  Dragon  Ground  108.0     170      115
# 712  646     KyuremBlack Kyurem  Dragon     Ice  125.0     170      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495      120       95     92           4      False
# 712      120       90     95           5       True

# %% [markdown]
# ##### Condizione multipla con AND

# %%
df[(df['Attack'] == 170) & (df['Defense'] > 100)]
# Out:
#        #                   Name  Type 1  Type 2     HP  Attack  Defense  \
# 495  445  GarchompMega Garchomp  Dragon  Ground  108.0     170      115
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495      120       95     92           4      False

# %% [markdown]
# ##### Condizione multipla con OR

# %%
df[(df['Attack'] == 170) | (df['Defense'] > 220)]
# Out:
#        #                   Name  Type 1   Type 2     HP  Attack  Defense  \
# 225  208    SteelixMega Steelix   Steel   Ground   75.0     125      230
# 231  213                Shuckle     Bug     Rock   20.0      10      230
# 334  306      AggronMega Aggron   Steel  No type   70.0     140      230
# 495  445  GarchompMega Garchomp  Dragon   Ground  108.0     170      115
# 712  646     KyuremBlack Kyurem  Dragon      Ice  125.0     170      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 225       55       95     30           2      False
# 231       10      230      5           2      False
# 334       60       80     50           3      False
# 495      120       95     92           4      False
# 712      120       90     95           5       True

# %% [markdown]
# ##### Condizione utilizzando la funzione isin( )

# %%
pokemon = ['Bulbasaur', 'Charmander', 'Squirtle']
df[df['Name'].isin(pokemon)]
# Out:
#     #        Name Type 1   Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1   Bulbasaur  Grass   Poison  69.0      49       49       65       65
# 5   4  Charmander   Fire  No type  39.0      52       43       60       50
# 10  7    Squirtle  Water  No type  44.0      48       65       50       64
#
#     Speed  Generation  Legendary
# 0      45           1      False
# 5      65           1      False
# 10     43           1      False

# %% [markdown]
# ##### Condizione per la quale è contenuta o no (~) una certa parola

# %%
df[df['Name'].str.contains('Charizard')]
# Out:
#    #                       Name Type 1  Type 2    HP  Attack  Defense  \
# 7  6                  Charizard   Fire  Flying  78.0      84       78
# 8  6  CharizardMega Charizard X   Fire  Dragon  78.0     130      111
# 9  6  CharizardMega Charizard Y   Fire  Flying  78.0     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7      109       85    100           1      False
# 8      130       85    100           1      False
# 9      159      115    100           1      False

# %%
df[~df['Name'].str.contains('Charizard')].head(5)
# Out:
#    #                   Name Type 1   Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass   Poison  69.0      49       49       65
# 1  2                Ivysaur  Grass   Poison  60.0      62       60       80
# 3  3               Venusaur  Grass   Poison  80.0      82       83      100
# 4  3  VenusaurMega Venusaur  Grass   Poison  80.0     100      123      122
# 5  4             Charmander   Fire  No type  39.0      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      100     80           1      False
# 4      120     80           1      False
# 5       50     65           1      False

# %% [markdown]
# ##### Condizione tramite regular expression

# %%
import re

# %%
# filtra le righe che contengono fire oppure grass all'interno della colonna Type 1
df[df['Type 1'].str.contains('fire|grass', flags=re.IGNORECASE, regex=True)].head(5)
# Out:
#    #                   Name Type 1   Type 2    HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass   Poison  69.0      49       49       65
# 1  2                Ivysaur  Grass   Poison  60.0      62       60       80
# 3  3               Venusaur  Grass   Poison  80.0      82       83      100
# 4  3  VenusaurMega Venusaur  Grass   Poison  80.0     100      123      122
# 5  4             Charmander   Fire  No type  39.0      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 3      100     80           1      False
# 4      120     80           1      False
# 5       50     65           1      False

# %%
# filtra le righe per cui la colonna Name inzia con _Pi_<br>
df[df['Name'].str.contains('^pi*', flags=re.IGNORECASE, regex=True)].head(5)

# ^ indica deve iniziare con (quindi deve iniziare con pi)<br>
# . indica un qualsiasi carattere ad eccezione di una nuova linea<br>
# * indica zero o più volte (si concatena con il .)
# Out:
#      #                 Name    Type 1   Type 2    HP  Attack  Defense  \
# 21  16               Pidgey    Normal   Flying  40.0      45       40
# 22  17            Pidgeotto    Normal   Flying  63.0      60       55
# 23  18              Pidgeot    Normal   Flying  83.0      80       75
# 24  18  PidgeotMega Pidgeot    Normal   Flying  83.0      80       80
# 31  25              Pikachu  Electric  No type  35.0      55       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 21       35       35     56           1      False
# 22       50       50     71           1      False
# 23       70       70    101           1      False
# 24      135       80    121           1      False
# 31       50       50     90           1      False

# %% [markdown]
# ### <span style='background :yellow'>Reset dell'index
#     Dopo aver eseguito subsetting sulle righe, l'index ovviamente ha numeri casuali, attraverso la funzione
#     reset_index() è possibile resettarlo

# %%
# index con numeri casuali dopo aver fatto subsetting
df[df['Attack'] == 170]
# Out:
#        #                   Name  Type 1  Type 2     HP  Attack  Defense  \
# 495  445  GarchompMega Garchomp  Dragon  Ground  108.0     170      115
# 712  646     KyuremBlack Kyurem  Dragon     Ice  125.0     170      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495      120       95     92           4      False
# 712      120       90     95           5       True

# %%
# index formattato dopo aver fatto subsetting
df[df['Attack'] == 170].reset_index(drop=True)
# Out:
#      #                   Name  Type 1  Type 2     HP  Attack  Defense  \
# 0  445  GarchompMega Garchomp  Dragon  Ground  108.0     170      115
# 1  646     KyuremBlack Kyurem  Dragon     Ice  125.0     170      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      120       95     92           4      False
# 1      120       90     95           5       True

# %% [markdown]
# ### <span style='background :yellow'>Conversione Series a Dataframe
#     Mediante la funzione to_frame() è possibile convertire una Series in un Dataframe

# %% [markdown]
# #### <span style='background :lime'>Funzione TO_FRAME( )

# %%
series = df['Attack']
type(series)
# Out:
# pandas.core.series.Series

# %%
series.to_frame('Attack')
# Out:
#      Attack
# 0        49
# 1        62
# 3        82
# 4       100
# 5        52
# ..      ...
# 796     100
# 797     160
# 798     110
# 799     160
# 800     110
#
# [800 rows x 1 columns]

# %% [markdown]
# ### <span style='background :yellow'>Modificare il dataframe

# %% [markdown]
# #### <span style='background :lime'>Aggiungere una colonna

# %% [markdown]
# ##### Metodo 1

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  69.0      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  60.0      62       60       80       80
# 3  3   Venusaur  Grass  Poison  80.0      82       83      100      100
#
#    Speed  Generation  Legendary  Total
# 0     45           1      False  342.0
# 1     60           1      False  402.0
# 3     80           1      False  525.0

# %% [markdown]
# ##### Metodo 2

# %%
df.loc[:,'Total(1)'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  69.0      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  60.0      62       60       80       80
# 3  3   Venusaur  Grass  Poison  80.0      82       83      100      100
#
#    Speed  Generation  Legendary  Total  Total(1)
# 0     45           1      False  342.0     342.0
# 1     60           1      False  402.0     402.0
# 3     80           1      False  525.0     525.0

# %% [markdown]
# ##### Metodo 3
# Questo modo è rischioso, perché se in futuro dovesse cambiare la posizione delle colonne (magari perchè prima è stata aggiunta una nuova colonna), il conto verrebbe fatto su colonne sbagliate

# %%
df['Total(2)'] = df.iloc[:,4:10].sum(axis=1)

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  69.0      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  60.0      62       60       80       80
# 3  3   Venusaur  Grass  Poison  80.0      82       83      100      100
#
#    Speed  Generation  Legendary  Total  Total(1)  Total(2)
# 0     45           1      False  342.0     342.0     342.0
# 1     60           1      False  402.0     402.0     402.0
# 3     80           1      False  525.0     525.0     525.0

# %% [markdown]
# ##### Metodo 4

# %%
# calcolo dell'indice di partenza e di fine
columns = list(df.columns) # ottengo il nome delle colonne come lista
start_index = columns.index('HP')
end_index = columns.index('Speed') + 1

# %%
df['Total(3)'] = df.iloc[:,start_index:end_index].sum(axis=1)

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  69.0      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  60.0      62       60       80       80
# 3  3   Venusaur  Grass  Poison  80.0      82       83      100      100
#
#    Speed  Generation  Legendary  Total  Total(1)  Total(2)  Total(3)
# 0     45           1      False  342.0     342.0     342.0     342.0
# 1     60           1      False  402.0     402.0     402.0     402.0
# 3     80           1      False  525.0     525.0     525.0     525.0

# %% [markdown]
# #### <span style='background :lime'>Spostare una o più colonne

# %%
columns = list(df.columns) # ottengo il nome delle colonne come lista
columns
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total',
#  'Total(1)',
#  'Total(2)',
#  'Total(3)']

# %%
df = df[columns[0:4] + columns[12:16] + columns[4:12]] # ricreo il dataframe con le colonne spostate di indice
df.head()

#N.B. anche in questo caso sarebbe meglio calcolarsi degli indici di partenza e fine
# Out:
#    #                   Name Type 1   Type 2  Total  Total(1)  Total(2)  \
# 0  1              Bulbasaur  Grass   Poison  342.0     342.0     342.0
# 1  2                Ivysaur  Grass   Poison  402.0     402.0     402.0
# 3  3               Venusaur  Grass   Poison  525.0     525.0     525.0
# 4  3  VenusaurMega Venusaur  Grass   Poison  625.0     625.0     625.0
# 5  4             Charmander   Fire  No type  309.0     309.0     309.0
#
#    Total(3)    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0     342.0  69.0      49       49       65       65     45           1
# 1     402.0  60.0      62       60       80       80     60           1
# 3     525.0  80.0      82       83      100      100     80           1
# 4     625.0  80.0     100      123      122      120     80           1
# 5     309.0  39.0      52       43       60       50     65           1
#
#    Legendary
# 0      False
# 1      False
# 3      False
# 4      False
# 5      False

# %% [markdown]
# #### <span style='background :lime'>Rimuovere una o più colonne - funzione DROP( )

# %%
df = df.drop(columns=['Total(1)','Total(2)','Total(3)'])
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison  342.0  69.0      49       49
# 1  2                Ivysaur  Grass   Poison  402.0  60.0      62       60
# 3  3               Venusaur  Grass   Poison  525.0  80.0      82       83
# 4  3  VenusaurMega Venusaur  Grass   Poison  625.0  80.0     100      123
# 5  4             Charmander   Fire  No type  309.0  39.0      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 3      100      100     80           1      False
# 4      122      120     80           1      False
# 5       60       50     65           1      False

# %% [markdown]
# #### <span style='background :lime'>Merge del dataframe con un altro - funzione MERGE( )

# %%
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison  342.0  69.0      49       49
# 1  2                Ivysaur  Grass   Poison  402.0  60.0      62       60
# 3  3               Venusaur  Grass   Poison  525.0  80.0      82       83
# 4  3  VenusaurMega Venusaur  Grass   Poison  625.0  80.0     100      123
# 5  4             Charmander   Fire  No type  309.0  39.0      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 3      100      100     80           1      False
# 4      122      120     80           1      False
# 5       60       50     65           1      False

# %%
# creazione di un dataframe da unire
df_to_merge = df[['Name']].copy()
df_to_merge['Characters'] = df_to_merge['Name'].apply(lambda x: len(x))
df_to_merge
# Out:
#                       Name  Characters
# 0                Bulbasaur           9
# 1                  Ivysaur           7
# 3                 Venusaur           8
# 4    VenusaurMega Venusaur          21
# 5               Charmander          10
# ..                     ...         ...
# 796                Diancie           7
# 797    DiancieMega Diancie          19
# 798    HoopaHoopa Confined          19
# 799     HoopaHoopa Unbound          18
# 800              Volcanion           9
#
# [800 rows x 2 columns]

# %%
# creazione di un nuovo dataframe che unisce i due precedenti
df_merged = df.merge(right=df_to_merge, left_on='Name', right_on='Name')
df_merged.head()
# Out:
#    #                   Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison  342.0  69.0      49       49
# 1  2                Ivysaur  Grass   Poison  402.0  60.0      62       60
# 2  3               Venusaur  Grass   Poison  525.0  80.0      82       83
# 3  3  VenusaurMega Venusaur  Grass   Poison  625.0  80.0     100      123
# 4  4             Charmander   Fire  No type  309.0  39.0      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Characters
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %% [markdown]
# ### <span style='background :yellow'>Modificare i dati

# %% [markdown]
# #### <span style='background :lime'>Cambiare il parametro della condizione
# Si vuole cambiare il Type _Fire_ in _Flame_

# %%
df[df['Type 1'] == 'Fire'].head(5)
# Out:
#    #                       Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 5  4                 Charmander   Fire  No type  309.0  39.0      52       43
# 6  5                 Charmeleon   Fire  No type  405.0  58.0      64       58
# 7  6                  Charizard   Fire   Flying  534.0  78.0      84       78
# 8  6  CharizardMega Charizard X   Fire   Dragon  634.0  78.0     130      111
# 9  6  CharizardMega Charizard Y   Fire   Flying  634.0  78.0     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 5       60       50     65           1      False
# 6       80       65     80           1      False
# 7      109       85    100           1      False
# 8      130       85    100           1      False
# 9      159      115    100           1      False

# %%
df_modified = df.copy()

# %%
df_modified.loc[df_modified['Type 1'] == 'Fire','Type 1'] = 'Flamer'

# %%
df_modified[df_modified['Type 1'] == 'Flamer'].head(5)
# Out:
#    #                       Name  Type 1   Type 2  Total    HP  Attack  \
# 5  4                 Charmander  Flamer  No type  309.0  39.0      52
# 6  5                 Charmeleon  Flamer  No type  405.0  58.0      64
# 7  6                  Charizard  Flamer   Flying  534.0  78.0      84
# 8  6  CharizardMega Charizard X  Flamer   Dragon  634.0  78.0     130
# 9  6  CharizardMega Charizard Y  Flamer   Flying  634.0  78.0     104
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 5       43       60       50     65           1      False
# 6       58       80       65     80           1      False
# 7       78      109       85    100           1      False
# 8      111      130       85    100           1      False
# 9       78      159      115    100           1      False

# %% [markdown]
# #### <span style='background :lime'>Cambiare un altro parametro sulla base di una condizione
# Si vuole mettere _Legendary_ = True se il pokemon ha forza totale maggiore di 700

# %%
df[df['Total'] >= 700].head()
# Out:
#        #                     Name   Type 1    Type 2  Total     HP  Attack  \
# 164  150      MewtwoMega Mewtwo X  Psychic  Fighting  780.0  106.0     190
# 165  150      MewtwoMega Mewtwo Y  Psychic   No type  780.0  106.0     150
# 269  248  TyranitarMega Tyranitar     Rock      Dark  700.0  100.0     164
# 410  373  SalamenceMega Salamence   Dragon    Flying  700.0   95.0     145
# 414  376  MetagrossMega Metagross    Steel   Psychic  700.0   80.0     145
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      100      154      100    130           1       True
# 165       70      194      120    140           1       True
# 269      150       95      120     71           2      False
# 410      130      120       90    120           3      False
# 414      150      105      110    110           3      False

# %%
df_modified = df.copy()
df_modified.loc[df_modified['Total'] >= 700,'Legendary'] = True

# %%
df_modified[df_modified['Total'] >= 700].head(5)
# Out:
#        #                     Name   Type 1    Type 2  Total     HP  Attack  \
# 164  150      MewtwoMega Mewtwo X  Psychic  Fighting  780.0  106.0     190
# 165  150      MewtwoMega Mewtwo Y  Psychic   No type  780.0  106.0     150
# 269  248  TyranitarMega Tyranitar     Rock      Dark  700.0  100.0     164
# 410  373  SalamenceMega Salamence   Dragon    Flying  700.0   95.0     145
# 414  376  MetagrossMega Metagross    Steel   Psychic  700.0   80.0     145
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      100      154      100    130           1       True
# 165       70      194      120    140           1       True
# 269      150       95      120     71           2       True
# 410      130      120       90    120           3       True
# 414      150      105      110    110           3       True

# %% [markdown]
# #### <span style='background :lime'>Cambiare più parametri sulla base di una condizione
# Si vuole mettere _Legendary_ = True e _Generation_ = 7 se il pokemon ha forza totale maggiore di 700

# %%
df[df['Total'] >= 700].head()
# Out:
#        #                     Name   Type 1    Type 2  Total     HP  Attack  \
# 164  150      MewtwoMega Mewtwo X  Psychic  Fighting  780.0  106.0     190
# 165  150      MewtwoMega Mewtwo Y  Psychic   No type  780.0  106.0     150
# 269  248  TyranitarMega Tyranitar     Rock      Dark  700.0  100.0     164
# 410  373  SalamenceMega Salamence   Dragon    Flying  700.0   95.0     145
# 414  376  MetagrossMega Metagross    Steel   Psychic  700.0   80.0     145
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      100      154      100    130           1       True
# 165       70      194      120    140           1       True
# 269      150       95      120     71           2      False
# 410      130      120       90    120           3      False
# 414      150      105      110    110           3      False

# %%
df_modified = df.copy()
df_modified.loc[df_modified['Total'] >= 700,['Generation','Legendary']] = [7,True]

# %%
df_modified[df_modified['Total'] >= 700].head(5)
# Out:
#        #                     Name   Type 1    Type 2  Total     HP  Attack  \
# 164  150      MewtwoMega Mewtwo X  Psychic  Fighting  780.0  106.0     190
# 165  150      MewtwoMega Mewtwo Y  Psychic   No type  780.0  106.0     150
# 269  248  TyranitarMega Tyranitar     Rock      Dark  700.0  100.0     164
# 410  373  SalamenceMega Salamence   Dragon    Flying  700.0   95.0     145
# 414  376  MetagrossMega Metagross    Steel   Psychic  700.0   80.0     145
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 164      100      154      100    130           7       True
# 165       70      194      120    140           7       True
# 269      150       95      120     71           7       True
# 410      130      120       90    120           7       True
# 414      150      105      110    110           7       True

# %% [markdown]
# #### <span style='background :lime'>Funzione APPLY( ) - Applicazione di una funzione lungo un asse (righe o colonne)

# %% [markdown]
# ##### Applicazione della funzione per la creazione di una nuova colonna (First name)

# %%
def getFirstName(x):
    return x.split(' ')[0]

df['First name'] = df['Name'].apply(lambda x: getFirstName(x))
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison  342.0  69.0      49       49
# 1  2                Ivysaur  Grass   Poison  402.0  60.0      62       60
# 3  3               Venusaur  Grass   Poison  525.0  80.0      82       83
# 4  3  VenusaurMega Venusaur  Grass   Poison  625.0  80.0     100      123
# 5  4             Charmander   Fire  No type  309.0  39.0      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary    First name
# 0       65       65     45           1      False     Bulbasaur
# 1       80       80     60           1      False       Ivysaur
# 3      100      100     80           1      False      Venusaur
# 4      122      120     80           1      False  VenusaurMega
# 5       60       50     65           1      False    Charmander

# %%
# ritorno alla situazione iniziale
df = df.drop(columns='First name')
df.head()
# Out:
#    #                   Name Type 1   Type 2  Total    HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass   Poison  342.0  69.0      49       49
# 1  2                Ivysaur  Grass   Poison  402.0  60.0      62       60
# 3  3               Venusaur  Grass   Poison  525.0  80.0      82       83
# 4  3  VenusaurMega Venusaur  Grass   Poison  625.0  80.0     100      123
# 5  4             Charmander   Fire  No type  309.0  39.0      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 3      100      100     80           1      False
# 4      122      120     80           1      False
# 5       60       50     65           1      False

# %% [markdown]
# ##### Applicazione della funzione per calcolare la media di ogni colonna (axis=0)

# %%
df['HP'].mean()
# Out:
# 69.28875

# %%
df[['HP','Attack']].apply(np.mean, axis=0).to_frame('Mean')
# Out:
#             Mean
# HP      69.28875
# Attack  79.00125

# %% [markdown]
# ##### Applicazione della funzione per calcolare la media di ogni riga (axis=1)

# %%
df[['HP','Attack']].apply(np.mean, axis=1).to_frame('HP-Attack mean')
# Out:
#      HP-Attack mean
# 0              59.0
# 1              61.0
# 3              81.0
# 4              90.0
# 5              45.5
# ..              ...
# 796            75.0
# 797           105.0
# 798            95.0
# 799           120.0
# 800            95.0
#
# [800 rows x 1 columns]

# %% [markdown]
# #### <span style='background :lime'>Funzione APPLYMAP( ) - Applicazione di una funzione su ogni singola cella

# %%
# elimino le colonne non numeriche e ad ogni cella applico la funzione int()
df.drop(columns=['Name','Type 1', 'Type 2']).applymap(lambda x: int(x))
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0      1    342  69      49       49       65       65     45           1
# 1      2    402  60      62       60       80       80     60           1
# 3      3    525  80      82       83      100      100     80           1
# 4      3    625  80     100      123      122      120     80           1
# 5      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 796  719    600  50     100      150      100      150     50           6
# 797  719    700  50     160      110      160      110    110           6
# 798  720    600  80     110       60      150      130     70           6
# 799  720    680  80     160       60      170      130     80           6
# 800  721    600  80     110      120      130       90     70           6
#
#      Legendary
# 0            0
# 1            0
# 3            0
# ...

# %% [markdown]
# ### <span style='background :yellow'>Statistica aggregata

# %% [markdown]
# #### <span style='background :lime'>Funzione GROUPBY( ) - caso 1 (grouped summaries)

# %%
df_total = df.groupby('Type 1')['Total'].mean().sort_values(ascending=False).reset_index()
df_total.head()
# Out:
#     Type 1       Total
# 0   Dragon  550.531250
# 1    Steel  487.703704
# 2   Flying  485.000000
# 3  Psychic  475.947368
# 4     Fire  458.076923

# %%
plt.figure(figsize=(14,6))

plt.barh(df_total['Type 1'], df_total['Total'])
plt.xlabel('Total')
plt.ylabel('Type 1')
plt.title('Total strenght per Type 1')

plt.xticks(ticks=np.arange(0,600,50))
plt.show()

# %% [markdown]
# #### <span style='background :lime'>Funzione GROUPBY( ) - caso 2 (multiple grouped summaries)

# %%
df_total = df.groupby('Type 1')['Total'].agg([min, max, np.mean]).reset_index()
df_total.head()
# Out:
#      Type 1    min    max        mean
# 0       Bug  194.0  600.0  378.927536
# 1      Dark  220.0  680.0  445.741935
# 2    Dragon  300.0  780.0  550.531250
# 3  Electric  205.0  610.0  443.409091
# 4     Fairy  218.0  680.0  413.176471

# %%
plt.figure(figsize=(14,6))

plt.barh(df_total['Type 1'], df_total['mean'], alpha = 0.5)
plt.barh(df_total['Type 1'], df_total['min'], alpha = 0.5)
plt.barh(df_total['Type 1'], df_total['max'], alpha = 0.5)
plt.xlabel('Total')
plt.ylabel('Type 1')
plt.title('Total strenght per Type 1')

plt.xticks(ticks=np.arange(0,850,50))
plt.show()

# %% [markdown]
# #### <span style='background :lime'>Funzione GROUPBY( ) - caso 3 (grouping by multiple variables)

# %%
df_total = df.groupby(['Type 1', 'Type 2'])['Total'].mean().sort_values(ascending=False).reset_index()
df_total.head()
# Out:
#    Type 1    Type 2       Total
# 0  Ground      Fire  770.000000
# 1  Dragon       Ice  686.666667
# 2   Ghost    Dragon  680.000000
# 3   Steel    Dragon  680.000000
# 4  Dragon  Electric  680.000000

# %%
df_total['Type'] = df_total['Type 1'] + ' - ' + df_total['Type 2']
df_total = df_total.drop(columns=['Type 1', 'Type 2'])
df_total = df_total[['Type', 'Total']] # ricreo il dataframe con le colonne spostate di indice
df_total.head()
# Out:
#                 Type       Total
# 0      Ground - Fire  770.000000
# 1       Dragon - Ice  686.666667
# 2     Ghost - Dragon  680.000000
# 3     Steel - Dragon  680.000000
# 4  Dragon - Electric  680.000000

# %% [markdown]
# #### <span style='background :lime'>Funzione GROUPBY( ) - caso 4 (many groups, many summaries)

# %%
df_total = df.groupby(['Type 1', 'Type 2'])[['Total', 'Attack']].mean().sort_values(['Total','Attack'], ascending=False).reset_index()
df_total.head()
# Out:
#     Type 1    Type 2       Total  Attack
# 0   Ground      Fire  770.000000   180.0
# 1   Dragon       Ice  686.666667   140.0
# 2  Psychic      Dark  680.000000   160.0
# 3   Dragon  Electric  680.000000   150.0
# 4   Dragon      Fire  680.000000   120.0

# %%
df_total['Type'] = df_total['Type 1'] + ' - ' + df_total['Type 2']
df_total = df_total.drop(columns=['Type 1', 'Type 2'])
df_total = df_total[['Type', 'Total', 'Attack']] # ricreo il dataframe con le colonne spostate di indice
df_total.head()
# Out:
#                 Type       Total  Attack
# 0      Ground - Fire  770.000000   180.0
# 1       Dragon - Ice  686.666667   140.0
# 2     Psychic - Dark  680.000000   160.0
# 3  Dragon - Electric  680.000000   150.0
# 4      Dragon - Fire  680.000000   120.0

# %% [markdown]
# #### <span style='background :lime'>Funzione GROUPBY( ) - conteggio

# %%
df.groupby('Type 1').count()[['#']]
# Out:
#             #
# Type 1
# Bug        69
# Dark       31
# Dragon     32
# Electric   44
# Fairy      17
# Fighting   27
# Fire       52
# Flying      4
# Ghost      32
# Grass      70
# Ground     32
# Ice        24
# Normal     98
# Poison     28
# Psychic    57
# Rock       44
# Steel      27
# Water     112

# %%
df.groupby(['Type 1','Type 2']).count()[['#']]
# df.groupby(['Type 1','Type 2']).count()['#'].to_frame('#') # come alternativa
# Out:
#                   #
# Type 1 Type 2
# Bug    Electric   2
#        Fighting   2
#        Fire       2
#        Flying    14
#        Ghost      1
# ...              ..
# Water  No type   59
#        Poison     3
#        Psychic    5
#        Rock       4
#        Steel      1
#
# [154 rows x 1 columns]
